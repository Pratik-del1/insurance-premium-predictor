# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report , accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category
# 0                        High
# 1                         Low
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         100 non-null    int64
#  1   weight                      100 non-null    float64
#  2   height                      100 non-null    float64
#  3   income_lpa                  100 non-null    float64
#  4   smoker                      100 non-null    bool
#  5   city                        100 non-null    object
#  6   occupation                  100 non-null    object
#  7   insurance_premium_category  100 non-null    object
# dtypes: bool(1), float64(3), int64(1), object(3)
# memory usage: 5.7+ KB

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category
# 0                        High
# 1                         Low
# ...

# %%
df['bmi'] = df['weight'] / (df['height'] ** 2)
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi
# 0                        High  49.227482
# ...

# %%
def lifestyle_risk(row):
    if row['smoker'] and row['bmi'] > 30:
        return 'high risk'
    elif row['smoker'] or row['bmi'] > 27:
        return 'medium risk'
    else:
        return 'low risk'

# %%
df['lifestyle_risk'] = df.apply(lifestyle_risk , axis = 1)

# %%
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi lifestyle_risk
# 0                        High  49.227482    medium risk
# ...

# %%
def age_group(age):
    if age < 25:
        return 'young'
    elif age < 45:
        return 'adult'
    elif age < 60:
        return 'middle_aged'
    else:
        return 'senior'

# %%
df['age_group'] = df['age'].apply(age_group)
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi lifestyle_risk    age_group
# ...

# %%
df['occupation'].unique()
# Out:
# array(['retired', 'freelancer', 'student', 'government_job',
#        'business_owner', 'unemployed', 'private_job'], dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Jaipur', 'Chennai', 'Indore', 'Mumbai', 'Kota', 'Hyderabad',
#        'Delhi', 'Chandigarh', 'Pune', 'Kolkata', 'Lucknow', 'Gaya',
#        'Jalandhar', 'Mysore', 'Bangalore'], dtype=object)

# %%
tier_1 = ['Chennai' , 'Delhi' , 'Mumbai' , 'Kolkata' , 'Pune' , 'Hyderabad' , 'Bangalore']
tier_2 = ['Jaipur' , 'Indore' , 'Kota' , 'Lucknow' , 'Chandigarh' , 'Jalandhar' , 'Mysore']

def city_tier(city):
    if city in tier_1:
        return 1
    elif city in tier_2:
        return 2
    else:
        return 3

# %%
df['city_tier'] = df['city'].apply(city_tier)

# %%
df
# Out:
#     age  weight  height  income_lpa  smoker       city      occupation  \
# 0    67   119.8    1.56     2.92000   False     Jaipur         retired
# 1    36   101.1    1.83    34.28000   False    Chennai      freelancer
# 2    39    56.8    1.64    36.64000   False     Indore      freelancer
# 3    22   109.4    1.55     3.34000    True     Mumbai         student
# 4    69    62.2    1.60     3.94000    True     Indore         retired
# ..  ...     ...     ...         ...     ...        ...             ...
# 95   36    52.8    1.57    19.64000   False     Indore  business_owner
# 96   26   113.8    1.54    34.01000   False      Delhi     private_job
# 97   52    60.8    1.80    44.86000   False  Hyderabad      freelancer
# 98   27   101.1    1.82    28.30000   False    Kolkata  business_owner
# 99   40    70.0    1.59    28.16664    True  Bangalore  government_job
#
#    insurance_premium_category        bmi lifestyle_risk    age_group  \
# ...

# %%
df1 = df[['income_lpa' , 'bmi' , 'age_group' , 'lifestyle_risk' , 'city_tier' , 'occupation' , 'insurance_premium_category']]

# %%
df1
# Out:
#     income_lpa        bmi    age_group lifestyle_risk  city_tier  \
# 0      2.92000  49.227482       senior    medium risk          2
# 1     34.28000  30.189017        adult    medium risk          1
# 2     36.64000  21.118382        adult       low risk          2
# 3      3.34000  45.535900        young      high risk          1
# 4      3.94000  24.296875       senior    medium risk          2
# ..         ...        ...          ...            ...        ...
# 95    19.64000  21.420747        adult       low risk          2
# 96    34.01000  47.984483        adult    medium risk          1
# 97    44.86000  18.765432  middle_aged       low risk          1
# 98    28.30000  30.521676        adult    medium risk          1
# 99    28.16664  27.688778        adult    medium risk          1
#
#         occupation insurance_premium_category
# 0          retired                       High
# 1       freelancer                        Low
# ...

# %%
x = df1[['bmi' , 'income_lpa' , 'age_group' , 'lifestyle_risk' , 'city_tier' , 'occupation']]
y = df1['insurance_premium_category']

# %%
categorical_feat = ['age_group' , 'lifestyle_risk' , 'city_tier' , 'occupation']
numerical_feat = ['bmi' , 'income_lpa']

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cat' , OneHotEncoder() , categorical_feat),
        ('num' , 'passthrough' , numerical_feat)
    ]
)

# %%
pipeline = Pipeline(steps = [
    ('preprocessor' , preprocessor),
    ('classifier' , RandomForestClassifier(random_state=42))
])

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1)
pipeline.fit(x_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   ['age_group',
#                                                    'lifestyle_risk',
#                                                    'city_tier', 'occupation']),
#                                                  ('num', 'passthrough',
#                                                   ['bmi', 'income_lpa'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
y_pred = pipeline.predict(x_test)
accuracy_score(y_test , y_pred)
# Out:
# 0.8

# %%
import pickle

pickle_model_path = 'model.pkl'
with open(pickle_model_path , 'wb') as f:
    pickle.dump(pipeline , f)
